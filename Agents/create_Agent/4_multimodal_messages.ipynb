# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")
agent = create_agent(
    model = model,
    system_prompt = " you are a cricket lover, create a plan to hit the yorker ball"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content = [
    {"type" : "text",
     "text" : "what is the perfect shot"
     }
])

response = agent.invoke(
    {
        "messages" : [question]
    }
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content=[{'type': 'text', 'text': 'what is the perfect shot'}], additional_kwargs={}, response_metadata={}, id='3b80d906-f12e-4cb3-91e0-330144c43af8'),
#               AIMessage(content='Ah, the yorker! The bowler\'s ultimate weapon, designed to shatter stumps and dreams. But for us batsmen, it\'s also a glorious challenge and a potential goldmine if you have the plan and the nerve!\n\nLet\'s break down how to conquer this beast.\n\n## Your Plan to Hit the Yorker Ball\n\n### 1. The Mindset: Anticipation, Not Fear\n\n*   **Expect it:** Especially in the death overs of T20s or when a bowler is looking for a breakthrough. Don\'t be surprised; be ready.\n*   **Positive Intent:** Don\'t just think defensively. Think about scoring opportunities. A well-executed yorker can still be a boundary.\n*   **Read the Bowler:** Look for subtle cues – the grip, the run-up, the angle of delivery. Is he trying to bowl a wide yorker, a leg-stump yorker, or straight at the base?\n\n### 2. Pre-Ball Preparation: Get Ready to Pounce\n\n*   **Balanced Stance:** Be on the balls of your feet, slightly coiled, ready to move in any direction.\n*   **High Bat Lift:** A good, high backlift allows you to bring the bat down quickly and straight.\n*   **Head Still, Eyes Focused:** This is non-negotiable for any shot, but especially crucial for a yorker where the margin for error is razor-thin. Spot the ball *early*.\n\n### 3. Execution: The Mechanics of Mastery\n\n*   **Early Spotting is Key:** As the bowler releases, pick up the line and length as quickly as humanly possible. This is where practice comes in.\n*   **Minimal Footwork, Maximum Impact:**\n    *   **Against a straight yorker:** A small, positive shuffle forward to meet the ball *before* it dips too low. You want to get your bat *under* it or *behind* it.\n    *   **Against a wide yorker:** A quick shuffle across to get your body in line with the ball, allowing you to reach it.\n*   **Straight Bat is Your Best Friend:** Bring your bat down as straight as possible, like a spear. This gives you the best chance to hit through the line or dig it out.\n*   **Strong Bottom Hand:** This is crucial for power and control, whether you\'re driving, digging out, or guiding.\n*   **Head Over the Ball:** Ensure your head is directly above the point of impact. This keeps you balanced and allows for precise execution.\n*   **Follow Through:** Even if it\'s just a defensive block, a slight follow-through ensures you\'ve committed to the shot and helps guide the ball away from the stumps.\n\n### 4. Shot Selection: What is the "Perfect Shot"?\n\nThere isn\'t *one* single "perfect shot" for every yorker, as it depends on the line, pace, and field setting. However, the goal is always to minimise risk and maximise reward.\n\nHere are your primary options, with the "perfect" leaning towards the **straight drive** if executed flawlessly:\n\n1.  **The Straight Drive / On-Drive (The Aggressive "Perfect" Option):**\n    *   **When:** When the yorker is full enough to get under and is relatively straight (either middle-leg or middle-off).\n    *   **How:** Get your front foot slightly forward, bring the bat down absolutely straight, *under* the ball, and drive through the line. The aim is to hit it along the ground past the bowler for four, or over the bowler\'s head if you have immense power and timing. This requires exceptional timing and getting your bat *under* the ball before it dips.\n    *   **Why it\'s "Perfect":** It\'s a classical, powerful, and high-scoring shot that shows complete dominance over the bowler\'s best delivery.\n\n2.  **The Defensive Block / Dig-Out (The Safe "Perfect" Option):**\n    *   **When:** When the ball is too fast, too straight, or too late to get under. Your primary goal is to protect your stumps.\n    *   **How:** Bring your bat down straight, angled slightly downwards, and dig the ball out into the ground. Soft hands are key to ensure it doesn\'t pop up for a catch.\n    *   **Why it\'s "Perfect":** Sometimes, the perfect shot is the one that saves your wicket and keeps you in the game. A single off a defensive push can also be gold.\n\n3. ...

# %% [markdown]
# Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept = '.png',multiple = False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'Screenshot 2026-01-13 001154.png', 'type': 'image/png', 'size': 438485, 'content': <memory at 0x000001E662443AC0>, 'last_modified': datetime.datetime(2026, 1, 12, 18, 41, 54, 361000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

uploaded_file = uploader.value[0]

#this is memory view
content_mv = uploaded_file["content"]

#convert memory view -> bytes

img_bytes = bytes(content_mv)

# encode base64

img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this paper"},{
    "type": "image_url",
    "image_url": {
        "url": f"data:image/png;base64,{img_b64}"
    }
}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# This appears to be a question from an examination paper, likely for an undergraduate-level course in **Compiler Design** or **Principles of Programming Languages**.
#
# Here's a breakdown of what this question (Question 4) is asking about:
#
# *   **Overall Subject:** The questions cover fundamental concepts in how programming languages are processed and executed, including compilation techniques, language semantics, and memory management.
#
# *   **Specific Topics in Question 4:**
#
#     *   **4.(a) Directed Acyclic Graphs (DAGs) in Code Optimization:** This part asks for a definition of DAGs and their significance in the optimization phase of a compiler. DAGs are used to represent basic blocks of code, helping compilers identify common subexpressions and perform various optimizations.
#         *   *(Marks: 3)*
#
#     *   **4.(b) Impure Interpreters and Scoping (Static vs. Dynamic):** This question has two parts: defining an "impure interpreter" (one that allows side effects or modifies its environment) and explaining the crucial difference between static (lexical) scoping and dynamic scoping, which determines how variables are resolved in a program, along with an example.
#         *   *(Marks: 3)*
#
#     *   **4.(c) Syntax Directed Translation (SDT) of SWITCH Statement:** This part requires an explanation of Syntax Directed Translation, a method used in compilers to attach semantic rules to grammar productions. It then asks specifically how SDT would be applied to translate a `SWITCH` (or `case`) statement into intermediate code or perform its semantic actions.
#         *   *(Marks: 3)*
#
#     *   **4.(d) Storage Allocation Strategies:** This question asks for a comparison of the three primary memory allocation strategies used by programming languages and operating systems: static allocation (for global/static variables), stack allocation (for local variables and function calls), and heap allocation (for dynamic memory).
#         *   *(Marks: 3)*
#
# In essence, this question tests a student's understanding of key theoretical and practical aspects of how programming languages are structured, translated, and executed by a computer system.
